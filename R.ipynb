# %%
import tarfile

tar_path = "GSE253462_RAW.tar"   # <-- make sure this matches your filename

tar = tarfile.open(tar_path, "r")

# list every item inside the tar (folders + files)
members = tar.getmembers()

for m in members:
    print(m.name)
